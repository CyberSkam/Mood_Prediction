# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:/Users/krian/Mood_Prediction/Preprocessed.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#       Unnamed: 0                                            CONTENT  \
# 0              0     sirjadeja  yes  firki  corrupts  blackmoney...
# 1              1     syedsulaiman92  telanganacmo  open  150  ce...
# 2              2     mdbaid  incompetence  modi  reason  nationa...
# 3              3  latest  awlwood  joinery  devon  times  daily ...
# 4              4  latest  business  breakthroughs  daily    coom...
# 5              5     vijaisardesai  kudos  margaomunicipalcounci...
# 6              6     dhume  chhibber  indias  demonetization  wo...
# 7              7     ajaymaken  janakroshmarch  demonetizationma...
# 8              8     aapgujarat  news  print  aap  protests  guj...
# 9              9  latest  forex  academy    com4orjggysp  thewor...
# 10            10  want  see  whatsapp  group  demonetization    ...
# 11            11     bsindia  bharathbandh  opposition  divided ...
# 12            12     aapgujarat  news  print  aap  protests  guj...
# ...

# %%
df.shape
# Out:
# (7770, 6)

# %%
df_0 = df.loc[df['label']==0]

# %%
df_0.shape
# Out:
# (3965, 6)

# %%
df_0.to_csv('C:/Users/krian/Mood_Prediction/Label0.csv')

# %%
pip install wordninja
# Out:
# ...
#   Stored in directory: C:\Users\krian\AppData\Local\pip\Cache\wheels\22\46\06\9b6d10ed02c85e93c3bb33ac50e2d368b2586248f192a2e22a
# Successfully built wordninja
# ...
# Note: you may need to restart the kernel to use updated packages.
